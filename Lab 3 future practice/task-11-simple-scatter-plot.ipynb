# %%
import matplotlib.pyplot as plt

#data
country = ['Canada', 'Australia', 'Saudi-Arabia', 'Italy', 'Germany']
rate = [43, 76, 64, 32, 27]

#ploting into bar chart
plt.scatter(country,rate)
plt.title("Visa Acceptance Rate")
plt.xlabel("Acceptance Rate")
plt.ylabel("Country Name")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       4 country = ['Canada', 'Australia', 'Saudi-Arabia', 'Italy', 'Germany']
#       5 rate = [43, 76, 64, 32, 27]
#       6
#       7 #ploting into bar chart
# ----> 8 plt.scatter(country,rate, color='cyan', width=0.5)
#       9 plt.title("Visa Acceptance Rate")
#      10 plt.xlabel("Acceptance Rate")
#      11 plt.ylabel("Country Name")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
# ...
