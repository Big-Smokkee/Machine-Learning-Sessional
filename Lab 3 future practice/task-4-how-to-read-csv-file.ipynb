# %%
import pandas as pd
data = pd.read_csv("data task 4.csv")
print(data)
# Out:
#                    Name  age  Contact number
# 0      Md. Fardin Faraz   24      1906780349
# 1        Md Liaquat Ali   78      1883637929
# 2  Sayed Mahbuba Khanom   60      1840020042
