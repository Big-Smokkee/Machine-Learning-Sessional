# %%
import pandas as pd
excel_data = pd.read_excel("17th Batch Supervisor Choice List for Capstone Project (Responses).xlsx")
print("Data is given below\n", excel_data)
# Out:
# Data is given below
#                  Timestamp       Student -1       Student -2   Student - 3  \
# 0 2026-04-17 22:05:43.195  822310105101064  822310205101072  8.223101e+14
# 1 2026-04-17 22:13:32.401  822310105101066  822310205101041  8.223102e+14
# 2 2026-04-17 22:20:09.244  822310205101028  822310205101003           NaN
# 3 2026-04-17 22:34:21.068  822310205101031  822310205101023           NaN
# 4 2026-04-17 22:42:33.852  822310105101073  822310105101046  8.223102e+14
# 5 2026-04-17 23:15:46.204  822310205101058  822310205101052  8.223102e+14
# 6 2026-04-17 23:53:07.260  822310105101039  822310105101022  8.223101e+14
# 7 2026-04-18 00:08:03.920  822310105101011  822310105101038  8.223101e+14
# 8 2026-04-18 08:43:36.101  822310105101019  822310105101006  8.223102e+14
#
#              Faculty Choice - 1            Faculty Choice - 2  \
# 0                  Afroza Islam                Saad Bin Kamal
# 1  Dr. Mohammed Mahmudur Rahman                           NaN
# ...
