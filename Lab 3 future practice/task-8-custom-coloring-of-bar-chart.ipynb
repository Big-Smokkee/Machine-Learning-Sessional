# %%
import matplotlib.pyplot as plt

# data
category = ["Dhaka", "Cumilla", "Rajshahi","Dinajpur"]
data = [20, 25, 17, 19]

plt.bar(category, data, color="red")
plt.xlabel("Category")
plt.ylabel("Crime Rate")
plt.title("Custom Coloring")
# plt.grid(True)
plt.show()
